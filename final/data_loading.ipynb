# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
#load data
df_trainids=pd.read_csv('data/Train_IDs.csv')
df_demo=pd.read_csv('data/demographics.csv')
df_loc=pd.read_csv('data/location.csv')
df_sat=pd.read_csv('data/satisfaction.csv')
df_serv=pd.read_csv('data/services.csv')
df_sta=pd.read_csv('data/status.csv')

# %%
#get all ids
id_set=set()
id_set.update(df_demo['Customer ID'].tolist())
id_set.update(df_loc['Customer ID'].tolist())
id_set.update(df_sat['Customer ID'].tolist())
id_set.update(df_serv['Customer ID'].tolist())
id_list=list(id_set)
#form data
df=pd.DataFrame(id_list,columns=['Customer ID'])
df.set_index('Customer ID',inplace=True)

# %%
# %%time
df.insert(0,'Gender',np.nan)
df.insert(1,'Age',np.nan)
df.insert(2,'Married',np.nan)
df.insert(3,'Number of Dependents',np.nan)
df.insert(4,'Zip Code',np.nan)
df.insert(5,'Satisfaction Score',np.nan)
df.insert(6,'Referred a Friend',np.nan)
df.insert(7,'Number of Referrals',np.nan)
df.insert(8,'Tenure in Months',np.nan)
df.insert(9,'Offer',np.nan)
df.insert(10,'Phone Service',np.nan)
df.insert(11,'Avg Monthly Long Distance Charges',np.nan)
df.insert(12,'Multiple Lines',np.nan)
df.insert(13,'Internet Service',np.nan)
df.insert(14,'Internet Type',np.nan)
df.insert(15,'Avg Monthly GB Download',np.nan)
df.insert(16,'Online Security',np.nan)
df.insert(17,'Online Backup',np.nan)
df.insert(18,'Device Protection Plan',np.nan)
df.insert(19,'Premium Tech Support',np.nan)
df.insert(20,'Streaming TV',np.nan)
df.insert(21,'Streaming Movies',np.nan)
df.insert(22,'Streaming Music',np.nan)
df.insert(23,'Unlimited Data',np.nan)
df.insert(24,'Contract',np.nan)
df.insert(25,'Paperless Billing',np.nan)
df.insert(26,'Payment Method',np.nan)
df.insert(27,'Monthly Charge',np.nan)
df.insert(28,'Total Charges',np.nan)
df.insert(29,'Total Refunds',np.nan)
df.insert(30,'Total Extra Data Charges',np.nan)
df.insert(31,'Total Long Distance Charges',np.nan)
df.insert(32,'Total Revenue',np.nan)

for i in range(6163):
    df.loc[df_demo.loc[i,'Customer ID'],'Gender']=df_demo.loc[i,'Gender']
    df.loc[df_demo.loc[i,'Customer ID'],'Age']=df_demo.loc[i,'Age']
    df.loc[df_demo.loc[i,'Customer ID'],'Married']=df_demo.loc[i,'Married']
    df.loc[df_demo.loc[i,'Customer ID'],'Number of Dependents']=df_demo.loc[i,'Number of Dependents']
    df.loc[df_loc.loc[i,'Customer ID'],'Zip Code']=df_loc.loc[i,'Zip Code']
    df.loc[df_sat.loc[i,'Customer ID'],'Satisfaction Score']=df_sat.loc[i,'Satisfaction Score']
    df.loc[df_serv.loc[i,'Customer ID'],'Referred a Friend']=df_serv.loc[i,'Referred a Friend']
    df.loc[df_serv.loc[i,'Customer ID'],'Number of Referrals']=df_serv.loc[i,'Number of Referrals']
    df.loc[df_serv.loc[i,'Customer ID'],'Tenure in Months']=df_serv.loc[i,'Tenure in Months']
    df.loc[df_serv.loc[i,'Customer ID'],'Offer']=df_serv.loc[i,'Offer']
    df.loc[df_serv.loc[i,'Customer ID'],'Phone Service']=df_serv.loc[i,'Phone Service']
    df.loc[df_serv.loc[i,'Customer ID'],'Avg Monthly Long Distance Charges']=df_serv.loc[i,'Avg Monthly Long Distance Charges']
    df.loc[df_serv.loc[i,'Customer ID'],'Multiple Lines']=df_serv.loc[i,'Multiple Lines']
    df.loc[df_serv.loc[i,'Customer ID'],'Internet Service']=df_serv.loc[i,'Internet Service']
    df.loc[df_serv.loc[i,'Customer ID'],'Internet Type']=df_serv.loc[i,'Internet Type']
    df.loc[df_serv.loc[i,'Customer ID'],'Avg Monthly GB Download']=df_serv.loc[i,'Avg Monthly GB Download']
    df.loc[df_serv.loc[i,'Customer ID'],'Online Security']=df_serv.loc[i,'Online Security']
    df.loc[df_serv.loc[i,'Customer ID'],'Online Backup']=df_serv.loc[i,'Online Backup']
    df.loc[df_serv.loc[i,'Customer ID'],'Device Protection Plan']=df_serv.loc[i,'Device Protection Plan']
    df.loc[df_serv.loc[i,'Customer ID'],'Premium Tech Support']=df_serv.loc[i,'Premium Tech Support']
    df.loc[df_serv.loc[i,'Customer ID'],'Streaming TV']=df_serv.loc[i,'Streaming TV']
    df.loc[df_serv.loc[i,'Customer ID'],'Streaming Movies']=df_serv.loc[i,'Streaming Movies']
    df.loc[df_serv.loc[i,'Customer ID'],'Streaming Music']=df_serv.loc[i,'Streaming Music']
    df.loc[df_serv.loc[i,'Customer ID'],'Unlimited Data']=df_serv.loc[i,'Unlimited Data']
    df.loc[df_serv.loc[i,'Customer ID'],'Contract']=df_serv.loc[i,'Contract']
    df.loc[df_serv.loc[i,'Customer ID'],'Paperless Billing']=df_serv.loc[i,'Paperless Billing']
    df.loc[df_serv.loc[i,'Customer ID'],'Payment Method']=df_serv.loc[i,'Payment Method']
    df.loc[df_serv.loc[i,'Customer ID'],'Monthly Charge']=df_serv.loc[i,'Monthly Charge']
    df.loc[df_serv.loc[i,'Customer ID'],'Total Charges']=df_serv.loc[i,'Total Charges']
    df.loc[df_serv.loc[i,'Customer ID'],'Total Refunds']=df_serv.loc[i,'Total Refunds']
    df.loc[df_serv.loc[i,'Customer ID'],'Total Extra Data Charges']=df_serv.loc[i,'Total Extra Data Charges']
    df.loc[df_serv.loc[i,'Customer ID'],'Total Long Distance Charges']=df_serv.loc[i,'Total Long Distance Charges']
    df.loc[df_serv.loc[i,'Customer ID'],'Total Revenue']=df_serv.loc[i,'Total Revenue']
#df['Zip Code']=df['Zip Code'].map(df['Zip Code'].value_counts.to_dict())#frequency encoding

df
# Out:
# CPU times: user 27.5 s, sys: 0 ns, total: 27.5 s
# Wall time: 27.5 s
#              Gender   Age Married  Number of Dependents  Zip Code  \
# Customer ID
# 4086-ATNFV     Male  64.0     NaN                   0.0   93262.0
# 9943-VSZUV     Male  36.0      No                   0.0       NaN
# 5277-ZLOOR     Male  25.0     Yes                   2.0   96015.0
# 7326-RIGQZ   Female   NaN     NaN                   0.0   94533.0
# 5060-TQUQN     Male  53.0      No                   0.0       NaN
# ...             ...   ...     ...                   ...       ...
# 1360-XFJMR   Female  29.0      No                   0.0       NaN
# 5451-YHYPW     Male   NaN     Yes                   0.0   95410.0
# 1452-XRSJV      NaN  63.0     Yes                   3.0   90601.0
# 6556-DBKZF   Female  31.0     NaN                   0.0       NaN
# 1481-ZUWZA      NaN  53.0     NaN                   0.0   91103.0
#
#              Satisfaction Score Referred a Friend  Number of Referrals  \
# Customer ID
# ...

# %%
df.to_csv('df.csv')
